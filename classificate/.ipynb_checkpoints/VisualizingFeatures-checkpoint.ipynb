# %%
import model
import torch

# %%
restore_model_from='classificator_'

# %%
net = model.Net()
net.load_state_dict(torch.load(restore_model_from, map_location='cpu' ))

# %%
def preprocess(path):
    im=torch.tensor(cv2.resize(np.array(cv2.imread(path)[:,:,::-1],dtype=np.float32)))
    im=(im-127.5)/127.5
    return im.permute(2,0,1)

# %%
PATH='C:\\Users\\ADMIN\\Desktop\\projectFacesss\\preproces_images\\'
net.eval()
net(torch.stack([preprocess(PATH+'AF1986.jpg'),preprocess(PATH+'AF1973.jpg')],dim=0))
# Out:
# tensor([[1.5308],
#         [4.2273]], grad_fn=<AddmmBackward>)

# %%
net(preprocess(PATH+'AF1986.jpg').unsqueeze(0))
# Out:
# tensor([[1.1509]], grad_fn=<AddmmBackward>)

# %%
y=torch.tensor(np.array([[1.016667,4.75]],dtype=np.float32))
x=torch.stack([preprocess(PATH+'AF1986.jpg'),preprocess(PATH+'AF1973.jpg')],dim=0)
saliency=compute_saliency_maps(x,y.float(),net)

# %%
plt.imshow(saliency[0])

# %%
def make_fooling_image(X, target_y, model):
    criterion = torch.nn.MSELoss()
    # Initialize our fooling image to the input image, and make it require gradient
    X_fooling = X.clone()
    X_fooling = X_fooling.requires_grad_(True)
    norm=0
    learning_rate = 1
    it=0
    while it<30:
        outputs = model(X_fooling)
        loss = criterion(outputs, torch.tensor([target_y]))
        loss.backward()
        X_fooling.data=X_fooling.data-learning_rate*X_fooling.grad.data/torch.norm(X_fooling.grad.data)
        it+=1
        print(it,torch.sum((outputs-target_y)**2))
        if torch.sum((outputs-target_y)**2)<1:
            break;
    print(it)

    return X_fooling

# %%
fool = make_fooling_image(preprocess(PATH+'AF1986.jpg').unsqueeze(0),torch.tensor(np.array([[10]],dtype=np.float32)),net)
# Out:
# 1 tensor(78.3066, grad_fn=<SumBackward0>)
# 2 tensor(65.9397, grad_fn=<SumBackward0>)
# 3 tensor(56.7410, grad_fn=<SumBackward0>)
# 4 tensor(47.4932, grad_fn=<SumBackward0>)
# 5 tensor(40.8801, grad_fn=<SumBackward0>)
# 6 tensor(35.8606, grad_fn=<SumBackward0>)
# 7 tensor(32.7333, grad_fn=<SumBackward0>)
# 8 tensor(30.6783, grad_fn=<SumBackward0>)
# 9 tensor(29.1814, grad_fn=<SumBackward0>)
# 10 tensor(28.0020, grad_fn=<SumBackward0>)
# 11 tensor(26.9754, grad_fn=<SumBackward0>)
# 12 tensor(26.0356, grad_fn=<SumBackward0>)
# 13 tensor(25.1426, grad_fn=<SumBackward0>)
# 14 tensor(24.2980, grad_fn=<SumBackward0>)
# 15 tensor(23.4660, grad_fn=<SumBackward0>)
# 16 tensor(22.6552, grad_fn=<SumBackward0>)
# 17 tensor(21.8654, grad_fn=<SumBackward0>)
# 18 tensor(21.0987, grad_fn=<SumBackward0>)
# 19 tensor(20.3457, grad_fn=<SumBackward0>)
# 20 tensor(19.6221, grad_fn=<SumBackward0>)
# 21 tensor(18.9119, grad_fn=<SumBackward0>)
# 22 tensor(18.2307, grad_fn=<SumBackward0>)
# ...

# %%
plt.imshow(fool[0].permute(1,2,0).detach().numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
